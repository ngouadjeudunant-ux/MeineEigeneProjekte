# %% [markdown]
# Promt Copilot : Ich bereite die MS-900 vor . Sie beträgt 15 Module und ich werde die 15 in unterschiedlichen chat lernen in diesem chat fangen wir an mit dem ersten Modul. Machen wir erstmal einen Kurs und dann eine Reihe von Aufgaben, die auf die Prüfung dran kommen könnten. Hier ist Link des ersten Modul:

# %% [markdown]
# Wortschaft
#
# Modul 1
#
# Hosten = héberger,   Rechenzentrum = centre de données ,  IT-Fußabdruck = parc informatique , benutzerdefiniert = personnalisé, Remotespeicher = stockage distant, Wartung = maintenance
# Server betreiben (exploiter) dans le sens de faire la maintenance et la gestion opérationnelle de l'infrastucture; patchen = appliquer un correctif, gewähren = octroyer (Zugriff gewähren : octroyer l'accès)
# sich verlagern = transférer (un responsabilité à quelqu'un par exemple)
